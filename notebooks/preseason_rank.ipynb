# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # This notebook consists all my work on finding the preseason rank and how accurate that was.

# %%
odds2015 = pd.read_csv('../data/odds2015.csv')
odds2016 = pd.read_csv('../data/odds2016.csv')
odds2017 = pd.read_csv('../data/odds2017.csv')
odds2018 = pd.read_csv('../data/odds2018.csv')
odds2019 = pd.read_csv('../data/odds2019.csv')
odds2022 = pd.read_csv('../data/odds2022.csv')
odds2023 = pd.read_csv('../data/odds2023.csv')
odds2024 = pd.read_csv('../data/odds2024.csv')
odds2025 = pd.read_csv('../data/odds2025.csv')

# %%
ranked_odds2015 = odds2015.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2016 = odds2016.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2017 = odds2017.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2018 = odds2018.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2019 = odds2019.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2022 = odds2022.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2023 = odds2023.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2024 = odds2024.sort_values(by='Stanley Cup Odds', ascending=True)
ranked_odds2025 = odds2025.sort_values(by='Stanley Cup Odds', ascending=True)

# %%
ranked_odds2015 = ranked_odds2015.reset_index(drop=True)
ranked_odds2015.index = np.arange(1, len(ranked_odds2015) + 1)
ranked_odds2015 = ranked_odds2015.rename_axis('rk').reset_index()
ranked_odds2015
# Out:
#     rk                   Team  Stanley Cup Odds  Pts. O/U Final Pts.
# 0    1     Chicago Blackhawks               700     110.5    102 (u)
# 1    2          Boston Bruins               850     107.5     96 (u)
# 2    3      Los Angeles Kings               900     104.5     95 (u)
# 3    4    Pittsburgh Penguins              1100     105.5     98 (u)
# 4    5          Anaheim Ducks              1200     105.0    109 (o)
# 5    6        St. Louis Blues              1200     104.5    109 (o)
# 6    7    Tampa Bay Lightning              1400      97.5    108 (o)
# 7    8        San Jose Sharks              1400     101.5     89 (u)
# 8    9       New York Rangers              1600      95.5    113 (o)
# 9   10     Montreal Canadiens              1800      95.5    110 (o)
# 10  11         Minnesota Wild              2000      99.5    100 (o)
# 11  12     Colorado Avalanche              2000      95.5     90 (u)
# 12  13           Dallas Stars              2500      95.5     92 (u)
# ...

# %%
ranked_odds2016 = ranked_odds2016.reset_index(drop=True)
ranked_odds2016.index = np.arange(1, len(ranked_odds2016) + 1)
ranked_odds2016 = ranked_odds2016.rename_axis('rk').reset_index()

# %%
ranked_odds2017 = ranked_odds2017.reset_index(drop=True)
ranked_odds2017.index = np.arange(1, len(ranked_odds2017) + 1)
ranked_odds2017 = ranked_odds2017.rename_axis('rk').reset_index()

# %%
ranked_odds2018 = ranked_odds2018.reset_index(drop=True)
ranked_odds2018.index = np.arange(1, len(ranked_odds2018) + 1)
ranked_odds2018 = ranked_odds2018.rename_axis('rk').reset_index()

# %%
ranked_odds2019 = ranked_odds2019.reset_index(drop=True)
ranked_odds2019.index = np.arange(1, len(ranked_odds2019) + 1)
ranked_odds2019 = ranked_odds2019.rename_axis('rk').reset_index()

# %%
ranked_odds2022 = ranked_odds2022.reset_index(drop=True)
ranked_odds2022.index = np.arange(1, len(ranked_odds2022) + 1)
ranked_odds2022 = ranked_odds2022.rename_axis('rk').reset_index()

# %%
ranked_odds2023 = ranked_odds2023.reset_index(drop=True)
ranked_odds2023.index = np.arange(1, len(ranked_odds2023) + 1)
ranked_odds2023 = ranked_odds2023.rename_axis('rk').reset_index()

# %%
ranked_odds2024 = ranked_odds2024.reset_index(drop=True)
ranked_odds2024.index = np.arange(1, len(ranked_odds2024) + 1)
ranked_odds2024 = ranked_odds2024.rename_axis('rk').reset_index()

# %%
top2_odds2015 = ranked_odds2015.head(2)
top2_odds2016 = ranked_odds2016.head(2)
top2_odds2017 = ranked_odds2017.head(2)
top2_odds2018 = ranked_odds2018.head(2)
top2_odds2019 = ranked_odds2019.head(2)
top2_odds2022 = ranked_odds2022.head(2)
top2_odds2023 = ranked_odds2023.head(2)
top2_odds2024 = ranked_odds2024.head(2)
top2_odds2025 = ranked_odds2025.head(2)

# %%
playoff2015 = pd.read_csv('../data/playoff2015.csv')
playoff2016 = pd.read_csv('../data/playoff2016.csv')
playoff2017 = pd.read_csv('../data/playoff2017.csv')
playoff2018 = pd.read_csv('../data/playoff2018.csv')
playoff2019 = pd.read_csv('../data/playoff2019.csv')
playoff2022 = pd.read_csv('../data/playoff2022.csv')
playoff2023 = pd.read_csv('../data/playoff2023.csv')
playoff2024 = pd.read_csv('../data/playoff2024.csv')
playoff2025 = pd.read_csv('../data/playoff2025.csv')

# %%
playoff2015
# Out:
#       Rk                 Team    GP     W     L    T   OW   OL   W-L%     G  \
# 0    1.0   Chicago Blackhawks  23.0  16.0   7.0  0.0  4.0  1.0  0.696  69.0
# 1    2.0  Tampa Bay Lightning  26.0  14.0  12.0  0.0  3.0  0.0  0.538  65.0
# 2    3.0        Anaheim Ducks  16.0  11.0   5.0  0.0  3.0  3.0  0.688  57.0
# 3    4.0     New York Rangers  19.0  11.0   8.0  0.0  4.0  1.0  0.579  45.0
# 4    5.0  Washington Capitals  14.0   7.0   7.0  0.0  1.0  3.0  0.500  28.0
# 5    6.0   Montreal Canadiens  12.0   6.0   6.0  0.0  2.0  1.0  0.500  25.0
# 6    7.0       Calgary Flames  11.0   5.0   6.0  0.0  1.0  1.0  0.455  27.0
# 7    8.0       Minnesota Wild  10.0   4.0   6.0  0.0  0.0  0.0  0.400  24.0
# 8    9.0   New York Islanders   7.0   3.0   4.0  0.0  1.0  1.0  0.429  15.0
# 9   10.0    Detroit Red Wings   7.0   3.0   4.0  0.0  0.0  1.0  0.429  15.0
# 10  11.0      Ottawa Senators   6.0   2.0   4.0  0.0  0.0  2.0  0.333  12.0
# ...
